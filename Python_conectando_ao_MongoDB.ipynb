# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelhenrick1/MongoDB/blob/main/Python_conectando_ao_MongoDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Aqui instalaremos a biblioteca pymongo para iniciarmos os nossos trabalhos!

# %%
# !python -m pip install pymongo

# %% [markdown]
# Com o código fornecido pelo MongoDB Cloud, iremos apenas alterar a senha:

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# Configure a URI com a senha
uri = "mongodb+srv://samuel__henrick:12345@cluster-fatec.int114q.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
from pymongo import MongoClient

# %% [markdown]
# É importante que o código acima seja executado toda vez que fecharmos algo.

# %% [markdown]
# Criaremos um banco de dados e salvamos na variável db.
# Criaremos também uma coleção dentro do banco de dados db_produtos e salvamos na variável coleção

# %%
db = client["db_produtos"]
collection = db["produtos"]

# %% [markdown]
# Verificando os bancos de dados que foram criados:

# %%
client.list_database_names()
# Out:
# ['db_produtos_desafio', 'admin', 'local']

# %% [markdown]
# Porque não apareceu o banco de dados produtos?
# Resposta: Poruque ela ainda não contém nenhum tipo de dado

# %% [markdown]
# Vamos inserir nosso primeiro dado?

# %%
product = {"produto" : "computador", "quantidade": 100}
collection.insert_one(product)

# %% [markdown]
# Verficando o que foi inserido na coleção:

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('652333aa33f5f7b6d5d83f51'),
#  'produto': 'computador',
#  'quantidade': 100}

# %% [markdown]
# Verificando as coleções:

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'db_produtos_desafio', 'admin', 'local']

# %% [markdown]
# Importando dados

# %%
import requests

# %%
response = requests.get("https://raw.githubusercontent.com/samuelhenrick1/MongoDB/main/produtos.json")

# %%
response.json()
# Out:
# [{'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 92.45,
#   'Frete': 5.6096965236,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'lat': -13.29,
#   'lon': -41.71},
#  {'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 43.84,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'lat': -22.19,
#   'lon': -48.79},
#  {'Produto': 'Pandeiro',
#   'Categoria do Produto': 'instrumentos musicais',
#   'Preço': 87.18,
#   'Frete': 2.2265117938,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'RJ',
#   'Avaliação da compra': 4,
# ...

# %% [markdown]
# Conferindo os dados que importamos!

# %%
len(response.json())
# Out:
# 9435

# %% [markdown]
# Inserindo dados na coleção

# %%
docs = collection.insert_many(response.json())

# %% [markdown]
# Conferindo quantas ids foram inseridas na base de dados

# %%
docs.inserted_ids
# Out:
# [ObjectId('652333ac33f5f7b6d5d83f52'),
#  ObjectId('652333ac33f5f7b6d5d83f53'),
#  ObjectId('652333ac33f5f7b6d5d83f54'),
#  ObjectId('652333ac33f5f7b6d5d83f55'),
#  ObjectId('652333ac33f5f7b6d5d83f56'),
#  ObjectId('652333ac33f5f7b6d5d83f57'),
#  ObjectId('652333ac33f5f7b6d5d83f58'),
#  ObjectId('652333ac33f5f7b6d5d83f59'),
#  ObjectId('652333ac33f5f7b6d5d83f5a'),
#  ObjectId('652333ac33f5f7b6d5d83f5b'),
#  ObjectId('652333ac33f5f7b6d5d83f5c'),
#  ObjectId('652333ac33f5f7b6d5d83f5d'),
#  ObjectId('652333ac33f5f7b6d5d83f5e'),
#  ObjectId('652333ac33f5f7b6d5d83f5f'),
#  ObjectId('652333ac33f5f7b6d5d83f60'),
#  ObjectId('652333ac33f5f7b6d5d83f61'),
#  ObjectId('652333ac33f5f7b6d5d83f62'),
#  ObjectId('652333ac33f5f7b6d5d83f63'),
#  ObjectId('652333ac33f5f7b6d5d83f64'),
#  ObjectId('652333ac33f5f7b6d5d83f65'),
#  ObjectId('652333ac33f5f7b6d5d83f66'),
#  ObjectId('652333ac33f5f7b6d5d83f67'),
#  ObjectId('652333ac33f5f7b6d5d83f68'),
#  ObjectId('652333ac33f5f7b6d5d83f69'),
# ...

# %%
len(docs.inserted_ids)
# Out:
# 9435

# %% [markdown]
# Conferindo o total de documentos

# %%
collection.count_documents({})
# Out:
# 9436

# %% [markdown]
# Deletando um banco de dados e um id de documento

# %%
db = client["fatec"]
collection = db["fatec"]

# %%
curso = {"curso" : "big data", "semestre": 6}
collection.insert_one(curso)

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('652333b533f5f7b6d5d8642d'),
#  'curso': 'big data',
#  'semestre': 6}

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'db_produtos_desafio', 'fatec', 'admin', 'local']

# %%
collection.find_one()["_id"]
# Out:
# ObjectId('652333b533f5f7b6d5d8642d')

# %%
id_remover = collection.find_one()["_id"]

# %%
print(id_remover);
# Out:
# 652333b533f5f7b6d5d8642d

# %%
collection.delete_one({"_id" :id_remover})

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'db_produtos_desafio', 'fatec', 'admin', 'local']

# %%
collection.find_one()

# %%
db_name = "fatec"

# %%
client.drop_database(db_name)

# %%
client.list_database_names()
# Out:
# ['db_produtos', 'db_produtos_desafio', 'admin', 'local']

# %% [markdown]
# Transformando dados

# %%
db = client["db_produtos"]
collection = db["produtos"]

# %%
collection.find()

# %%
for doc in collection.find():
    print(doc)
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# {'_id': ObjectId('652333ac33f5f7b6d5d843db'), 'Produto': 'TV Led UHD 4K', 'Categoria do Produto': 'eletronicos', 'Preço': 3209.26, 'Frete': 171.4145447755, 'Data da Compra': '04/11/2021', 'Vendedor': 'João Souza', 'Local da compra': 'RJ', 'Avaliação da compra': 2, 'Tipo de pagamento': 'cartao_credito', 'Quantidade de parcelas': 6, 'Latitude': -22.25, 'Longitude': -42.66}
# {'_id': ObjectId('652333ac33f5f7b6d5d843dc'), 'Produto': 'Fogão', 'Categoria do Produto': 'eletrodomesticos', 'Preço': 1003.26, 'Frete': 53.9468417784, 'Data da Compra': '04/11/2021', 'Vendedor': 'João Souza', 'Local da compra': 'SP', 'Avaliação da compra': 3, 'Tipo de pagamento': 'boleto', 'Quantidade de parcelas': 1, 'Latitude': -22.19, 'Longitude': -48.79}
# ...

# %%
collection.update_many({}, {'$rename': {'lat': 'Latitude', 'lon': 'Longitude'}})

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('652333ac33f5f7b6d5d83f52'),
#  'Produto': 'Modelagem preditiva',
#  'Categoria do Produto': 'livros',
#  'Preço': 92.45,
#  'Frete': 5.6096965236,
#  'Data da Compra': '01/01/2020',
#  'Vendedor': 'Thiago Silva',
#  'Local da compra': 'BA',
#  'Avaliação da compra': 1,
#  'Tipo de pagamento': 'cartao_credito',
#  'Quantidade de parcelas': 3,
#  'Latitude': -13.29,
#  'Longitude': -41.71}

# %% [markdown]
# Aplicando filtros

# %%
collection.distinct('Categoria do Produto')
# Out:
# ['brinquedos',
#  'eletrodomesticos',
#  'eletronicos',
#  'esporte e lazer',
#  'instrumentos musicais',
#  'livros',
#  'moveis',
#  'utilidades domesticas']

# %%
query = { "Categoria do Produto": "livros" }

lista_livros = []
for doc in collection.find(query):
    lista_livros.append(doc)

# %%
print(doc)
# Out:
# {'_id': ObjectId('652333ac33f5f7b6d5d86429'), 'Produto': 'Dashboards com Power BI', 'Categoria do Produto': 'livros', 'Preço': 54.85, 'Frete': 3.4517020142, 'Data da Compra': '31/12/2022', 'Vendedor': 'Lucas Oliveira', 'Local da compra': 'RJ', 'Avaliação da compra': 5, 'Tipo de pagamento': 'cartao_credito', 'Quantidade de parcelas': 3, 'Latitude': -22.25, 'Longitude': -42.66}

# %%
lista_livros
# Out:
# [{'_id': ObjectId('652333ac33f5f7b6d5d83f52'),
#   'Produto': 'Modelagem preditiva',
#   'Categoria do Produto': 'livros',
#   'Preço': 92.45,
#   'Frete': 5.6096965236,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 1,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 3,
#   'Latitude': -13.29,
#   'Longitude': -41.71},
#  {'_id': ObjectId('652333ac33f5f7b6d5d83f53'),
#   'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 43.84,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2020',
#   'Vendedor': 'Mariana Ferreira',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'Latitude': -22.19,
#   'Longitude': -48.79},
#  {'_id': ObjectId('652333ac33f5f7b6d5d83f65'),
#   'Produto': 'Iniciando em programação',
#   'Categoria do Produto': 'livros',
#   'Preço': 63.25,
# ...

# %% [markdown]
# Salvando em CSV

# %%
import pandas as pd

# %%
df_livros =  pd.DataFrame(lista_livros)
df_livros.head()
# Out:
#                         _id                      Produto Categoria do Produto  \
# 0  652333ac33f5f7b6d5d83f52          Modelagem preditiva               livros
# 1  652333ac33f5f7b6d5d83f53     Iniciando em programação               livros
# 2  652333ac33f5f7b6d5d83f65     Iniciando em programação               livros
# 3  652333ac33f5f7b6d5d83f73  Ciência de dados com python               livros
# 4  652333ac33f5f7b6d5d83f75  Ciência de dados com python               livros
#
#    Preço     Frete Data da Compra          Vendedor Local da compra  \
# 0  92.45  5.609697     01/01/2020      Thiago Silva              BA
# 1  43.84  0.000000     01/01/2020  Mariana Ferreira              SP
# 2  63.25  3.894137     01/01/2022     Juliana Costa              RJ
# 3  86.13  5.273176     01/02/2021    Camila Ribeiro              RJ
# 4  72.75  1.458158     01/02/2021    Beatriz Moraes              PR
#
#    Avaliação da compra Tipo de pagamento  Quantidade de parcelas  Latitude  \
# ...

# %% [markdown]
# Formatando dados

# %%
df_livros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     742 non-null    object
#  1   Produto                 742 non-null    object
#  2   Categoria do Produto    742 non-null    object
#  3   Preço                   742 non-null    float64
#  4   Frete                   742 non-null    float64
#  5   Data da Compra          742 non-null    object
#  6   Vendedor                742 non-null    object
#  7   Local da compra         742 non-null    object
#  8   Avaliação da compra     742 non-null    int64
#  9   Tipo de pagamento       742 non-null    object
#  10  Quantidade de parcelas  742 non-null    int64
#  11  Latitude                742 non-null    float64
#  12  Longitude               742 non-null    float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 75.5+ KB

# %%
df_livros["Data da Compra"] = pd.to_datetime(df_livros["Data da Compra"], format="%d/%m/%Y")
df_livros.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 742 entries, 0 to 741
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   _id                     742 non-null    object
#  1   Produto                 742 non-null    object
#  2   Categoria do Produto    742 non-null    object
#  3   Preço                   742 non-null    float64
#  4   Frete                   742 non-null    float64
#  5   Data da Compra          742 non-null    datetime64[ns]
#  6   Vendedor                742 non-null    object
#  7   Local da compra         742 non-null    object
#  8   Avaliação da compra     742 non-null    int64
#  9   Tipo de pagamento       742 non-null    object
#  10  Quantidade de parcelas  742 non-null    int64
#  11  Latitude                742 non-null    float64
#  12  Longitude               742 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(6)
# ...

# %%
df_livros["Data da Compra"] = df_livros["Data da Compra"].dt.strftime("%Y-%m-%d")
df_livros.head()
# Out:
#                         _id                      Produto Categoria do Produto  \
# 0  652333ac33f5f7b6d5d83f52          Modelagem preditiva               livros
# 1  652333ac33f5f7b6d5d83f53     Iniciando em programação               livros
# 2  652333ac33f5f7b6d5d83f65     Iniciando em programação               livros
# 3  652333ac33f5f7b6d5d83f73  Ciência de dados com python               livros
# 4  652333ac33f5f7b6d5d83f75  Ciência de dados com python               livros
#
#    Preço     Frete Data da Compra          Vendedor Local da compra  \
# 0  92.45  5.609697     2020-01-01      Thiago Silva              BA
# 1  43.84  0.000000     2020-01-01  Mariana Ferreira              SP
# 2  63.25  3.894137     2022-01-01     Juliana Costa              RJ
# 3  86.13  5.273176     2021-02-01    Camila Ribeiro              RJ
# 4  72.75  1.458158     2021-02-01    Beatriz Moraes              PR
#
#    Avaliação da compra Tipo de pagamento  Quantidade de parcelas  Latitude  \
# ...

# %%
df_livros.to_csv('/content/tabela_livros.csv', index=False)

# %% [markdown]
# Filtrando produtos vendidos:

# %%
collection.find_one()
# Out:
# {'_id': ObjectId('652333ac33f5f7b6d5d83f52'),
#  'Produto': 'Modelagem preditiva',
#  'Categoria do Produto': 'livros',
#  'Preço': 92.45,
#  'Frete': 5.6096965236,
#  'Data da Compra': '01/01/2020',
#  'Vendedor': 'Thiago Silva',
#  'Local da compra': 'BA',
#  'Avaliação da compra': 1,
#  'Tipo de pagamento': 'cartao_credito',
#  'Quantidade de parcelas': 3,
#  'Latitude': -13.29,
#  'Longitude': -41.71}

# %%
query = {"Data da Compra": {"$regex": "/202[1-9]"}}

# %%
lista_produtos = []
for doc in collection.find(query):
    lista_produtos.append(doc)

# %%
lista_produtos
# Out:
# [{'_id': ObjectId('652333ac33f5f7b6d5d83f5b'),
#   'Produto': 'Xadrez de madeira',
#   'Categoria do Produto': 'brinquedos',
#   'Preço': 25.23,
#   'Frete': 0.0,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'Thiago Silva',
#   'Local da compra': 'BA',
#   'Avaliação da compra': 5,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 2,
#   'Latitude': -13.29,
#   'Longitude': -41.71},
#  {'_id': ObjectId('652333ac33f5f7b6d5d83f5c'),
#   'Produto': 'Impressora',
#   'Categoria do Produto': 'eletronicos',
#   'Preço': 322.04,
#   'Frete': 14.7321002401,
#   'Data da Compra': '01/01/2021',
#   'Vendedor': 'João Souza',
#   'Local da compra': 'SP',
#   'Avaliação da compra': 3,
#   'Tipo de pagamento': 'cartao_credito',
#   'Quantidade de parcelas': 1,
#   'Latitude': -22.19,
#   'Longitude': -48.79},
#  {'_id': ObjectId('652333ac33f5f7b6d5d83f5d'),
#   'Produto': 'Mesa de centro',
#   'Categoria do Produto': 'moveis',
#   'Preço': 282.22,
# ...

# %%
df_produtos = pd.DataFrame(lista_produtos)
df_produtos.head()
# Out:
#                         _id            Produto Categoria do Produto    Preço  \
# 0  652333ac33f5f7b6d5d83f5b  Xadrez de madeira           brinquedos    25.23
# 1  652333ac33f5f7b6d5d83f5c         Impressora          eletronicos   322.04
# 2  652333ac33f5f7b6d5d83f5d     Mesa de centro               moveis   282.22
# 3  652333ac33f5f7b6d5d83f5e        Tablet ABXY          eletronicos  1100.42
# 4  652333ac33f5f7b6d5d83f5f              Fogão     eletrodomesticos   791.81
#
#        Frete Data da Compra        Vendedor Local da compra  \
# 0   0.000000     01/01/2021    Thiago Silva              BA
# 1  14.732100     01/01/2021      João Souza              SP
# 2  12.611805     01/01/2021      João Souza              SP
# 3  68.451348     01/01/2021  Beatriz Moraes              SP
# 4  42.444626     01/01/2021   Juliana Costa              SP
#
#    Avaliação da compra Tipo de pagamento  Quantidade de parcelas  Latitude  \
# ...

# %%
df_produtos["Data da Compra"] = pd.to_datetime(df_produtos["Data da Compra"], format="%d/%m/%Y")

# %%
df_produtos['Data da Compra'] = df_produtos['Data da Compra'].dt.strftime('%Y-%m-%d')

# %%
df_produtos.head()
# Out:
#                         _id            Produto Categoria do Produto    Preço  \
# 0  652333ac33f5f7b6d5d83f5b  Xadrez de madeira           brinquedos    25.23
# 1  652333ac33f5f7b6d5d83f5c         Impressora          eletronicos   322.04
# 2  652333ac33f5f7b6d5d83f5d     Mesa de centro               moveis   282.22
# 3  652333ac33f5f7b6d5d83f5e        Tablet ABXY          eletronicos  1100.42
# 4  652333ac33f5f7b6d5d83f5f              Fogão     eletrodomesticos   791.81
#
#        Frete Data da Compra        Vendedor Local da compra  \
# 0   0.000000     2021-01-01    Thiago Silva              BA
# 1  14.732100     2021-01-01      João Souza              SP
# 2  12.611805     2021-01-01      João Souza              SP
# 3  68.451348     2021-01-01  Beatriz Moraes              SP
# 4  42.444626     2021-01-01   Juliana Costa              SP
#
#    Avaliação da compra Tipo de pagamento  Quantidade de parcelas  Latitude  \
# ...

# %%
df_produtos.to_csv('/content/tb_2021_em_diante.csv', index=False)

# %% [markdown]
# Encerrando a conexão

# %%
client.close()
